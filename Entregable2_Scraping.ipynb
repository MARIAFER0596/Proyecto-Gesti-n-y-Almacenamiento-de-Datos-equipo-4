# %% [markdown]
# <a href="https://colab.research.google.com/github/MARIAFER0596/Proyecto-Gesti-n-y-Almacenamiento-de-Datos-equipo-4/blob/main/Entregable2_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Vistas HTML de la pagina**

# %%
import requests
import pandas as pd
url = "https://www.bbc.com/mundo/topics/c95y3rnzwkwt"

#user agent
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36 OPR/121.0.0.0",
    "Accept-Language":"es-Es,es;q=0.9",
    "Accept-Encoding":"gzip, deflate, br"
}
resp = requests.get(url, headers=headers)

print(resp.status_code)   #200
print(resp.text[:1000])   # imprime un fragmento del HTML recibido
resp.text
# Out:
# 200
# ...

# %%
#Webscraping
# Contenedor principal div id= main-wrapper
# titulares: class="bbc-1tzeti0"
# titular: li class bbc-t44f9r

#link a href

#textos del titular: h2 class

from bs4 import BeautifulSoup

#Configuracion Soup:
soup = BeautifulSoup(resp.text, "html.parser")


contenedor = soup.find("div", id="main-wrapper")
titulares = contenedor.find_all("li", class_="bbc-t44f9r")

titulares
noticias = []

for t in titulares:
    # Título
    titulo_tag = t.find("h2")
    titulo = titulo_tag.get_text(strip=True) if titulo_tag else None

    # Link
    link_tag = t.find("a", href=True)
    link = link_tag["href"] if link_tag else None
    if link and not link.startswith("http"):  # normalizar links relativos
        link = "https://www.bbc.com" + link

    # Fecha / hora
    fecha_tag = t.find("time")
    fecha = fecha_tag.get_text(strip=True) if fecha_tag else None

    # Imagen
    img_tag = t.find("img")
    img = img_tag["src"] if img_tag else None

    if titulo and link:
        noticias.append({
            "titulo": titulo,
            "link": link,
            "fecha": fecha,
            "imagen": img
        })

# Convertir a DataFrame
df_bbc= pd.DataFrame(noticias)
print(df.head())

# También imprimir bonito
for n in noticias[:5]:
    print(f"Titulo {n['titulo']}")
    print(f"Link🔗 {n['link']}")
    print(f"Fecha 📅 {n['fecha']}")
    print(f"Imagen🖼️ {n['imagen']}\n")
# Out:
#                                  source           author  \
# 0  {'id': None, 'name': 'Hipertextual'}   Azucena Martín
# 1    {'id': None, 'name': 'Xataka.com'}  Amparo Babiloni
# 2  {'id': None, 'name': 'Hipertextual'}   Azucena Martín
# 3    {'id': None, 'name': 'Xataka.com'}  Amparo Babiloni
# 4  {'id': None, 'name': 'Hipertextual'}   Azucena Martín
#
#                                                title  \
# 0  Los expertos dicen que ser amable es bueno par...
# 1  Delirios en directo y suicidios alimentados po...
# 2  Las parejas lo comparten todo, incluso los tra...
# 3  El suicidio de un adolescente desató una crisi...
# 4  ¿No has dormido suficiente? Este sencillo truc...
#
#                                          description  \
# 0  Muchas personas piensan solo en sí mismas y cr...
# 1  Una mujer llamada Kendra se ha hecho viral en ...
# 2  Da igual si hay separación de bienes o no, lo ...
# 3  Los chatbots de IA están en el punto de mira p...
# ...

# %% [markdown]
# # **API NEWS API**

# %%
#Configuracion con APIs
news_api_key = "9c0c058d261c46d49c3beda680b37974"   # reemplaza con tu key de NewsAPI


cabecera = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36",
    "Accept-Language":"es-ES,es;q=0.9,en;q=0.8"
}


#2. Obtener las noticias
url_news = f"https://newsapi.org/v2/everything?q=salud+mental&language=es&apiKey={news_api_key}"
resp_news = requests.get(url_news, headers=cabecera)

noticias_news = []
if resp_news.status_code == 200:
    data = resp_news.json()["articles"][:3]  # 3 noticias de prueba
    for art in data:
        noticias_news.append({
            "titulo": art["title"],
            "descripcion": art["description"],
            "url": art["url"],
            "fecha": art.get("publishedAt", ""),
            "imagen": art["urlToImage"]
        })

df_news = pd.DataFrame(noticias_news)

# %% [markdown]
# # API GPT

# %%
from openai import OpenAI
openai_api_key = ""  # reemplaza con tu key de OpenAI

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
# Inicializar cliente OpenAI
client = OpenAI(api_key=openai_api_key)
#3. Procesar con chatgpt las noticias de la api y del scraping

df_todas = pd.concat([df_bbc, df_news], ignore_index=True)


# 5. PROCESAR CON CHATGPT

resumenes = []
for _, fila in df_todas.iterrows():
    titulo = fila["titulo"]
    descripcion = fila["descripcion"]

    prompt = f"""
    Tengo esta noticia de salud mental:
    Título: {titulo}
    Descripción: {descripcion}

    Por favor, genera un resumen breve (máx 3 líneas) y dime la relevancia del tema en salud mental.
    """

    respuesta = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "Eres un analista de noticias especializado en salud mental."},
            {"role": "user", "content": prompt}
        ]
    )

    resumen = respuesta.choices[0].message.content
    resumenes.append(resumen)

df_todas["analisis_chatgpt"] = resumenes


# 6. RESULTADO FINAL
print(df_todas[["titulo", "url", "analisis_chatgpt"]])
# Out:
#                                                titulo  \
# 0   Cómo sobrevivir a la muerte del amor de tu vid...
# 1   Los padres de un adolescente que se quitó la v...
# 2   Las conmovedoras experiencias de una doctora q...
# 3   5 herramientas sencillas que ayudan a lidiar c...
# 4   La alerta de un jefe de Microsoft por el aumen...
# 5   "Un escape de la soledad": las tiendas de Seúl...
# 6   Lo que un "terapeuta de ricos" aprendió sobre ...
# 7   "Son personas peligrosas": los miles de soldad...
# 8   Las lecciones que aprendió el hombre que vivió...
# 9   5 consejos para lidiar con un "vampiro emocion...
# 10  El "efecto umbral": ¿por qué se nos olvida lo ...
# 11  "Me volví adicta a las compras. Este problema ...
# 12  "Mi papá empezó a espiar y a forzar a mi mamá"...
# 13  Qué pasa en nuestro cerebro entre los 6 y los ...
# 14  Qué aprendió la periodista que diseñó un exper...
# 15  "El latino trae un caos necesario a la vida de...
# ...

# %% [markdown]
# # Convertir audio

# %%
# !pip install elevenlabs
# !pip install python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 955.6/955.6 kB 38.0 MB/s eta 0:00:00
# ...

# %%
from dotenv import load_dotenv
from elevenlabs.client import ElevenLabs
from elevenlabs.play import play
import os

# %%
from IPython.display import Audio, display
from elevenlabs import ElevenLabs

ELEVENLABS_API_KEY = "sk_73026647df43fab63bd9f152a502f5fe996f9760b647714a"

# Inicializar cliente ElevenLabs
elevenlabs = ElevenLabs(api_key=ELEVENLABS_API_KEY)

# Convertir solo los primeros 3 resúmenes en audios
for i, texto in enumerate(resumenes[:3]):
    audio_stream = elevenlabs.text_to_speech.convert(
        text=texto,
        voice_id="JBFqnCBsd6RMkjVDRZzb",   # Voz predefinida
        model_id="eleven_multilingual_v2", # Modelo multilenguaje (sirve para español)
        output_format="mp3_44100_128"
    )

    # Unir fragmentos de audio
    audio_data = b"".join(audio_stream)

    # Guardar en archivo
    with open(f"resumen_noticia_{i+1}.mp3", "wb") as f:
        f.write(audio_data)

    print(f" Archivo resumen_noticia_{i+1}.mp3 creado ")

    # Reproducir en Colab/local
    display(Audio(audio_data, autoplay=True))
# Out:
#  Archivo resumen_noticia_1.mp3 creado
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Archivo resumen_noticia_2.mp3 creado
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Archivo resumen_noticia_3.mp3 creado
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 4. Convertir resumen a audio
for i, texto in enumerate(resumenes):
    audio = client.audio.speech.create(
        model="gpt-4o-mini-tts",   # modelo TTS
        voice="alloy",             # voz disponible
        input=texto
    )
    with open(f"resumen_noticia_{i+1}.mp3", "wb") as f:
        f.write(audio.read())
    print(f"Archivo resumen_noticia_{i+1}.mp3 creado ✅")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2356526991.py in <cell line: 0>()
#       1 # 4. Convertir resumen a audio
#       2 for i, texto in enumerate(resumenes):
# ----> 3     audio = client.audio.speech.create(
#       4         model="gpt-4o-mini-tts",   # modelo TTS
#       5         voice="alloy",             # voz disponible
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/audio/speech.py in create(self, input, model, voice, instructions, response_format, speed, stream_format, extra_headers, extra_query, extra_body, timeout)
#     101         """
#     102         extra_headers = {"Accept": "application/octet-stream", **(extra_headers or {})}
# --> 103         return self._post(
#     104             "/audio/speech",
#     105             body=maybe_transform(
#
# ...
